# %% [markdown]
# # Lab 2 - Newton-Raphson Rootfinding Method
# ## January 30 - February 4, 2023
# ## Student 1 Name: Aditya Tanna Student 1 ID No. 202103023
# ## Student 2 Name: Vraj Thakker Student 2 ID No. 202103052
# ## Student 3 Name: Kaniskh Dad Student 3 ID No. 202103005
# ## Date of Submission: 01/02/2023
# ***

# %%
import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative
import sympy as sym

# %%
import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative




x= smp.symbols("x")



f= str(input("enter function = "))
#diff = str(input("enter derivative of function"))
f= eval(f)
diff = str(f.diff(x))
f=str(f)
#diff=str(diff)
x = float(input("enter initial assumed root = "))

print('')
print('f = ', f)
print('')
print('derivative = ',diff)
print('')

def root(f,diff,x):
      
      iteration = 0 
      error_difference = 1
      
      arrays_of_root= []
      iteration_no =[]
      

      while(   eval(f) != 0    and    (abs(error_difference) != 0)  ):
       

        if eval(diff)==0:
          print("function has derivative as 0 ")
          break
# Formulae for Newton-Raphson Method
        new_app          =        x - eval(f)/eval(diff)
        error_difference =        new_app - x
        x                =        new_app
       
        iteration+=1
       
# appending the arrays_of_root and iteration
        arrays_of_root       =    nump.append(arrays_of_root,x)
        iteration_no =    nump.append(iteration_no,iteration)        
       

        print('iteration no =',iteration, '       root=', x , '       error difference =',  error_difference)
      return iteration , x , iteration_no,arrays_of_root

# function call and values return
iteration,x,iteration_no,arrays_of_root= root(f,diff,x)

#array of error 
arrays_of_error = arrays_of_root - x
print(arrays_of_root)

relative_error=[0]
for i in range(0,len(arrays_of_error)-1):
  a = arrays_of_error[i+1]/arrays_of_error[i]
  relative_error= nump.append(relative_error,a)

relative_error2=[0]
for i in range(0,len(arrays_of_error)-1):
  a = arrays_of_error[i+1]/((arrays_of_error[i])**3)
  relative_error2= nump.append(relative_error2,a)



print('')
print('no of iteration required = ',iteration ,'root of equation = ',x)
print('')

plt.plot(iteration_no, relative_error, color='r')
plt.plot(iteration_no, relative_error2, color='b')
plt.legend()
plt.show()

# 2*(x*3) - 9(x**2) + 12*x + 15
#   3.0001     2.9999      3.01     2.99

# %% [markdown]
# ### Q.1 Write a function `mynewtonraphson` that takes in two function names/handles `f` and `df`, and an initial point `x0` and outputs the estimate of the root `r` of the function `f`

# %%
# Write the Function mynewtonraphson below:
# def mynewtonraphson(f,df,x0):

import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative

x= smp.symbols("x")



f= str(input("enter function = "))
#diff = str(input("enter derivative of function"))
f= eval(f)
diff = str(f.diff(x))
f=str(f)
#diff=str(diff)
x = float(input("enter initial assumed root = "))

print('')
print('f = ', f)
print('')
print('derivative = ',diff)
print('')

def root(f,diff,x):
      
      iteration = 0 
      error_difference = 1
      
      arrays_of_root= []
      iteration_no =[]
      

      while(   eval(f) != 0    and    (abs(error_difference) != 0)  ):
       

        if eval(diff)==0:
          print("function has derivative as 0 ")
          break
# Formulae for Newton-Raphson Method
        new_app          =        x - eval(f)/eval(diff)
        error_difference =        new_app - x
        x                =        new_app
       
        iteration+=1
       
# Appending the arrays_of_root and iteration
        arrays_of_root       =    nump.append(arrays_of_root,x)
        iteration_no =    nump.append(iteration_no,iteration)        
       

        #print('iteration no =',iteration, '       root=', x , '       error difference =',  error_difference)
      return iteration , x , iteration_no,arrays_of_root

# function call and values return
iteration,x,iteration_no,arrays_of_root= root(f,diff,x)



print('')
print('no of iteration required = ',iteration ,'                         root of equation = ',x)
print('')


# 2*(x**3) - 9*(x**2) + 12*x + 15

# %%
# Functions and their derivatives whose roots are to be computed. You may define more functions 
# f1(x) and df1(x) and so on, for various function examples.
# def f(x):




# def df(x):

# %%
## Run a few examples of root-finding with Newton-Raphson method in this cell
# Plot x_n against n for a few examples.



import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative




x= smp.symbols("x")



f= str(input("enter function = "))
#diff = str(input("enter derivative of function"))
f= eval(f)
diff = str(f.diff(x))
f=str(f)
#diff=str(diff)
x = float(input("enter initial assumed root = "))

print('')
print('f = ', f)
print('')
print('derivative = ',diff)
print('')

def root(f,diff,x):
      
      iteration = 0 
      error_difference = 1
      
      arrays_of_root= []
      iteration_no =[]
      

      while(   eval(f) != 0    and    (abs(error_difference) != 0)  ):
       

        if eval(diff)==0:
          print("function has derivative as 0 ")
          break
# Formulae for Newton-Raphson Method
        new_app          =        x - eval(f)/eval(diff)
        error_difference =        new_app - x
        x                =        new_app
       
        iteration+=1
       
# appending the arrays_of_root and iteration
        arrays_of_root       =    nump.append(arrays_of_root,x)
        iteration_no =    nump.append(iteration_no,iteration)        
       

        print('iteration no =',iteration, '       root=', x , '       error difference =',  error_difference)
      return iteration , x , iteration_no,arrays_of_root

# function call and values return
iteration,x,iteration_no,arrays_of_root= root(f,diff,x)


print(arrays_of_root)



print('')
print('no of iteration required = ',iteration ,'root of equation = ',x)
print('')

plt.plot(iteration_no, arrays_of_root, color='r')



plt.show()

# 2*(x**3) - 9*(x**2) + 12*x + 15plt.plot(iteration_no, relative_error2, color='b')plt.plot(iteration_no, f, color='y')plt.legend()
# Out:
# enter function = 2*(x**3) - 9*(x**2) + 12*x + 15
# enter initial assumed root = 3.0001
#
# f =  2*x**3 - 9*x**2 + 12*x + 15
#
# derivative =  6*x**2 - 18*x + 12
#
# iteration no = 1        root= 1.0002999725029589        error difference = -1.9998000274970413
# iteration no = 2        root= 11116.464096917014        error difference = 11115.46379694451
# iteration no = 3        root= 7411.476079579837        error difference = -3704.9880173371776
# iteration no = 4        root= 4941.484075486234        error difference = -2469.992004093602
# iteration no = 5        root= 3294.8227505959458        error difference = -1646.6613248902886
# iteration no = 6        root= 2197.048550705098        error difference = -1097.7741998908477
# iteration no = 7        root= 1465.1991090403626        error difference = -731.8494416647354
# iteration no = 8        root= 977.2995183766961        error difference = -487.89959066366646
# ...

# %% [markdown]
# ***
# ### Q.2 For a few examples of different functions, plot $\frac{|x_{n+1} - r|}{|x_{n} - r|}$ and $\frac{|x_{n+1} - r|}{|x_{n} - r|^2}$ against $n$.

# %%
# Write a few examples of function f and derivatives df, and plot the above ratio. 
# Create additional cells below, if required.
import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative




x= smp.symbols("x")



f= str(input("enter function = "))
#diff = str(input("enter derivative of function"))
f= eval(f)
diff = str(f.diff(x))
f=str(f)
#diff=str(diff)
x = float(input("enter initial assumed root = "))

print('')
print('f = ', f)
print('')
print('derivative = ',diff)
print('')

def root(f,diff,x):
      
      iteration = 0 
      error_difference = 1
      
      arrays_of_root= []
      iteration_no =[]
      

      while(   eval(f) != 0    and    (abs(error_difference) != 0)  ):
       

        if eval(diff)==0:
          print("function has derivative as 0 ")
          break
# Formulae for Newton-Raphson Method
        new_app          =        x - eval(f)/eval(diff)
        error_difference =        new_app - x
        x                =        new_app
       
        iteration+=1
       
# appending the arrays_of_root and iteration
        arrays_of_root       =    nump.append(arrays_of_root,x)
        iteration_no =    nump.append(iteration_no,iteration)        
       

        print('iteration no =',iteration, '       root=', x , '       error difference =',  error_difference)
      return iteration , x , iteration_no,arrays_of_root

# function call and values return
iteration,x,iteration_no,arrays_of_root= root(f,diff,x)


print(arrays_of_root)



print('')
print('no of iteration required = ',iteration ,'root of equation = ',x)
print('')

plt.plot(iteration_no, arrays_of_root, color='r')



plt.show()

plt.plot(iteration_no, relative_error2, color='b')
plt.plot(iteration_no, f, color='y')
plt.legend()




# 2*(x**3) - 9*(x**2) + 12*x + 15

# %% [markdown]
# ***
# ### Q.3 Compare the speed of covergence of Newton-Raphson method with Bisection method for computing square root of positive numbers by plotting x_n against n, or various initializations x_0

# %%
# Copy-paste your Bisection Method code here
# def mybisection(p,eps):
from itertools import product
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np  
def mysqrt(p,eps):

    if p > 1:
        hi,low,number_of_iteration= p,1,0
    else:
        hi,low,number_of_iteration = 1,p,0


# for p > 1
    # As z_low = 1-p (-ve) and z_hi = p**2-p (+ve)
# for p < 1
    # As z_low = p**2-p (-ve) and z_hi = 1-p(+ve)

# and in both the cases (z_lo)*(z_hi)<0

    iteration_no = []
    root_in_each_iteration = []
    y = (hi + low)/2
    z = y**2 - p
# z =({1-p}/2)**2

    while (abs(z) > eps):
        z = y ** 2 - p
        number_of_iteration = number_of_iteration + 1
        if(z>0):  # as z_lo is -ve and z_y i.e.(z_({1+p}/2) is+ve so -ve * +ve < 0
            hi = y
        elif(z<0):     # as z_lo is -ve and z_y i.e.(z_({1+p}/2) is-ve so -ve * -ve > 0
            low = y
        else:
          hi=low=y
# as z is +ve initially always so hi is always set to (hi + low)/2 in the very first iteration.

        y = (hi + low) / 2
        range= hi-low
        iteration_no = np.append(iteration_no,number_of_iteration)
        root_in_each_iteration = np.append(root_in_each_iteration,y)
        print('iteration_no =', number_of_iteration, '    hi=',hi, '  low=',low,'   z=',z,'   y=',y,'   range=',range)
    return y,number_of_iteration,root_in_each_iteration,iteration_no

p = float(input())
eps = float(input())

y,number_of_iteration,root_in_each_iteration,iteration_no = mysqrt(p,eps)
diff = np.abs(y-root_in_each_iteration)
print(diff)



#plt.plot(iteration_no, realtive_error, color='r' )
plt.plot(iteration_no,root_in_each_iteration , color='b')
plt.legend() 
plt.show()

# %%
from itertools import product
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sympy import *

p=float(input())
eps=float(input("Eps:"))
n = [0]
X_n = []
z = x**2 - p
fderivative = z.diff(x)
xn = int(input("Initial root value:"))
Xn = np.append(X_n,5)
i=1
print("We're considering 1st interation with initially assumed value",xn)
while(true):
    a=xn
    Xn = np.append(Xn,xn)
    n= np.append(n,i)
    xn = xn - float(z.evalf(subs= {x:xn})) / float(fderivative.evalf(subs= {x:xn}))
    d=abs(a-xn)
    print(f'The {i+1} iteration xn is {xn:.2}')
    i+=1
    if(d < eps):
        break  

plt.xlim(1,i)
plt.plot(n,Xn, color='r')

# %% [markdown]
# ## <font color='red'> A.3: Write your comments/observation here  <font>
# The number of iterations for finding the roots will be less in the N-R method than the bisection method because the order of convergence of N-R method is two compared to the linear convergence in bisection method. Quadratic convergence ensures that the significant digits double in each iteration whereas there is no such gauranteed multiplicity in the number of significant digits in the bisection method. If we take the value for $p$ in $x^2 -p$ as 0.25 we get the root 0.5 in the $5^{th}$ iteration whereas for the same example bisection method takes about 7 iterations. Even for larger values we might identify N-R method to be more effective. We tried calculating for $p =4489$ and N-R method with initial value = 3 gave the root = 67 in about the 7th iteration where as bisection method took about 13 iterations. There are some loopholes in the N-R method which need to be taken care of like f'(x) must not be equal to zero and there shouldn't be oscillating values of $X_n$. We can observe the nature of two graphs of the above methods and conclude for various values of $p$ and initial values of $X_n$ and observe that the N-R takes less number of iterations for finding the root.

# %% [markdown]
# ***
# ### Q.4: Experiment with the Newton-Raphson method for finding roots of the function $f(x) = 2x^3-9x^2+12x+15$, with initial estimate around the point $x=3$. Explain the behaviour

# %%
# Write functions for f(x) and df(x) below

import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative


x= smp.symbols("x")


f= str(input("enter function = "))
#diff = str(input("enter derivative of function"))
f= eval(f)
diff = str(f.diff(x))
f=str(f)
#diff=str(diff)

print('')
print('f = ', f)
print('')
print('derivative = ',diff)
print('')


#   2*(x*3) - 9(x**2) + 12*x + 15
#   3.0001     2.9999      3.01     2.99

# %%
import numpy as nump
import matplotlib.pyplot as plt
import sympy as smp
import scipy as sp
from scipy.misc import derivative




x= smp.symbols("x")



f= str(input("enter function = "))
#diff = str(input("enter derivative of function"))
f= eval(f)
diff = str(f.diff(x))
f=str(f)
#diff=str(diff)
x = float(input("enter initial assumed root = "))

print('')
print('f = ', f)
print('')
print('derivative = ',diff)
print('')

def root(f,diff,x):
      
      iteration = 0 
      error_difference = 1
      
      arrays_of_root= []
      iteration_no =[]
      

      while(   eval(f) != 0    and    (abs(error_difference) != 0)  ):
       

        if eval(diff)==0:
          print("function has derivative as 0 ")
          break
# Formulae for Newton-Raphson Method
        new_app          =        x - eval(f)/eval(diff)
        error_difference =        new_app - x
        x                =        new_app
       
        iteration+=1
       
# appending the arrays_of_root and iteration
        arrays_of_root       =    nump.append(arrays_of_root,x)
        iteration_no =    nump.append(iteration_no,iteration)        
       

        #print('iteration no =',iteration, '       root=', x , '       error difference =',  error_difference)
      return iteration , x , iteration_no,arrays_of_root

# function call and values return
iteration,x,iteration_no,arrays_of_root= root(f,diff,x)

#array of error 
arrays_of_error = arrays_of_root - x
print(arrays_of_root)

realtive_error=[0]
for i in range(0,len(arrays_of_error)-1):
  a = arrays_of_error[i+1]/arrays_of_error[i]
  realtive_error= nump.append(realtive_error,a)

relative_error2=[0]
for i in range(0,len(arrays_of_error)-1):
  a = arrays_of_error[i+1]/((arrays_of_error[i])**3)
  relative_error2= nump.append(relative_error2,a)



print('')
print('no of iteration required = ',iteration ,'root of equation = ',x)
print('')

plt.plot(iteration_no, arrays_of_root, color='r')
#plt.plot(iteration_no, relative_error2, color='b')
plt.legend()
plt.show()

# 2*(x*3) - 9(x**2) + 12*x + 15
#   3.0001     2.9999      3.01     2.99

# %% [markdown]
# ## <font color='red'> A.4: Write your comments/observation here  <font>
# <font color = 'black'> When we plot the graph for x=3 we do not get any root as or we will get 1 as the root as f'(1) = 0 ,so in the next iteration we will get root as - $infty$ hence no root is possible
# -   for x= 3.0001 we will get a graph for which the first iteration gives 1.0002999725029589 as the root and the very second iteration will give 11116.464096917014 as a root which is diverging but after this iteration the function converges to root
# -  for x = 2.9999  we will get a negative graph i.e in negative y  which is also same initially diverges and then converges so root in first iteration is 0.9996999724970408  and in second iteration root is -11105.76039284899 after which it converges to root.
# -  for x=3.01 we will get a graph which diverges and converges alternatively and finally converges to the root.
# -  for x=2.99 we will get a graph similar to graph of 2.9999 but the values will be different
